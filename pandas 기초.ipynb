# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
# Series? -> 정수 index값을 기본적으로 포함한 1차원 자료배열
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s.values
# series의 값만 확인
s = pd.Series([1,3,6,8], index=['a','b','c','d'])
# series 값/인덱스 변경 O
s
# Out:
# a    1
# b    3
# c    6
# d    8
# dtype: int64

# %%
dates = pd.date_range('20200101', periods=6)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682
# 2020-01-04 -1.485980 -0.310791  1.664451 -1.943485
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683
# 2020-01-06 -0.478874  2.536959 -0.001792 -0.745353

# %%
df2 = pd.DataFrame({'A' : 1.0,
                   'B' : pd.Timestamp('20200102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3]*4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo'
                   })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2020-01-02  1.0  3   test  foo
# 1  1.0 2020-01-02  1.0  3  train  foo
# 2  1.0 2020-01-02  1.0  3   test  foo
# 3  1.0 2020-01-02  1.0  3  train  foo

# %%
df2.dtypes
# 결과물의 데이터 타입 확인
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.tail(3)
# 끝에서 마지막 3줄
df.head(3)
# 위에서 처음 3줄
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682

# %%
df.index
# index , 열column , numpy데이터 세부정보
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.describe()
# 대략적 통계 정보
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.934941  0.549201 -0.041081 -0.749797
# std    0.908443  1.875608  1.670820  0.987825
# min   -1.816116 -2.503185 -2.324420 -1.943485
# 25%   -1.660737 -0.192170 -0.935145 -1.325416
# 50%   -1.060748  0.624800 -0.314060 -1.010518
# 75%   -0.518034  2.013446  1.247890 -0.098827
# max    0.525827  2.536959  2.079685  0.691053

# %%
df.T
# 데이터 전치 -> index와 column 뒤바꿈
# Out:
#    2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# A   -1.816116   -0.635515   -1.718989   -1.485980    0.525827   -0.478874
# B   -2.503185    2.322626    0.163695   -0.310791    1.085905    2.536959
# C   -1.038084   -0.626327   -2.324420    1.664451    2.079685   -0.001792
# D    0.691053   -1.341994    0.116682   -1.943485   -1.275683   -0.745353

# %%
df.sort_index(axis=1, ascending=False)
# 축별로 정렬
# Out:
#                    D         C         B         A
# 2020-01-01  0.691053 -1.038084 -2.503185 -1.816116
# 2020-01-02 -1.341994 -0.626327  2.322626 -0.635515
# 2020-01-03  0.116682 -2.324420  0.163695 -1.718989
# 2020-01-04 -1.943485  1.664451 -0.310791 -1.485980
# 2020-01-05 -1.275683  2.079685  1.085905  0.525827
# 2020-01-06 -0.745353 -0.001792  2.536959 -0.478874

# %%
df.sort_values(by='B')
# 값별로 정렬 -> 지금은 B의 데이터가 작은 순서대로 배열
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-04 -1.485980 -0.310791  1.664451 -1.943485
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-06 -0.478874  2.536959 -0.001792 -0.745353

# %%
df['A']
# Getting데이터얻기 -> df.A와 동일한 Series 생성하는 단일 열 선택
# Out:
# 2020-01-01   -1.816116
# 2020-01-02   -0.635515
# 2020-01-03   -1.718989
# 2020-01-04   -1.485980
# 2020-01-05    0.525827
# 2020-01-06   -0.478874
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# [] -> 행 분할
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682

# %%
df['20200101':'20200103']
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682

# %%
df.loc[dates[0]]
# Label통한 선택 -> 횡단면 획득(0번째 dates의 값 얻어옴)
# Out:
# A   -1.816116
# B   -2.503185
# C   -1.038084
# D    0.691053
# Name: 2020-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# : -> index축은 전체 , A B 축만 얻어옴
# df.loc[dates[0],['A','B']] -> 0번째 date
# df.loc['20200102':'20200104', ['A','B']] -> index축 & A,B 축 얻어옴
# Out:
#                    A         B
# 2020-01-01 -1.816116 -2.503185
# 2020-01-02 -0.635515  2.322626
# 2020-01-03 -1.718989  0.163695
# 2020-01-04 -1.485980 -0.310791
# 2020-01-05  0.525827  1.085905
# 2020-01-06 -0.478874  2.536959

# %%
df.loc['20200101',['A','B']]
# 단일 차원 객체 반환
# Out:
# A   -1.816116
# B   -2.503185
# Name: 2020-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# 스칼라값(하나의 값인듯)
# = df.at[dates[0],'A'] (<- 더 빠른 연산 O)
# Out:
# -1.8161156284647455

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682
# 2020-01-04 -1.485980 -0.310791  1.664451 -1.943485
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683
# 2020-01-06 -0.478874  2.536959 -0.001792 -0.745353

# %%
df.iloc[3]
# 위치로 선택 -> 넘겨받은 위치(3번째줄)를 기준으로 선택
# Out:
# A   -1.485980
# B   -0.310791
# C    1.664451
# D   -1.943485
# Name: 2020-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# 3:5 -> 3~4! (맨 마지막은 포함X)
# 0:2 -> 마찬가지
# Out:
#                    A         B
# 2020-01-04 -1.485980 -0.310791
# 2020-01-05  0.525827  1.085905

# %%
df.iloc[1:3,:]
# 행 나누기(열은 : = 그대로 있어라~)
df.iloc[:,1:3]
# 열 나누기
# Out:
#                    B         C
# 2020-01-01 -2.503185 -1.038084
# 2020-01-02  2.322626 -0.626327
# 2020-01-03  0.163695 -2.324420
# 2020-01-04 -0.310791  1.664451
# 2020-01-05  1.085905  2.079685
# 2020-01-06  2.536959 -0.001792

# %%
df.iloc[1,1]
# 명시적으로 값 얻기
# 마찬가지 df.iat[1,1] -> 빠른 연산
# Out:
# 2.3226259717763167

# %%
df[df.A>0]
# A 데이터를 기준, 0보다 큰 녀석들만 보여줌
# Out:
#                    A         B         C         D
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683

# %%
df[df>0]
# Boolean조건 충족하는 데이터프레임 값 추출
# Out:
#                    A         B         C         D
# 2020-01-01       NaN       NaN       NaN  0.691053
# 2020-01-02       NaN  2.322626       NaN       NaN
# 2020-01-03       NaN  0.163695       NaN  0.116682
# 2020-01-04       NaN       NaN  1.664451       NaN
# 2020-01-05  0.525827  1.085905  2.079685       NaN
# 2020-01-06       NaN  2.536959       NaN       NaN

# %%
df2 = df.copy()
df2['E'] = ['one','one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053    one
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994    one
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682    two
# 2020-01-04 -1.485980 -0.310791  1.664451 -1.943485  three
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683   four
# 2020-01-06 -0.478874  2.536959 -0.001792 -0.745353  three

# %%
df2[df2['E'].isin(['two','four'])]
# 필터링을 위한 메소드 isin() -> 해당 값만 불러옴
# Out:
#                    A         B         C         D     E
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682   two
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683  four

# %%
# 새로운 열 설정
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20200101',periods=6))
s1
# Out:
# 2020-01-01    1
# 2020-01-02    2
# 2020-01-03    3
# 2020-01-04    4
# 2020-01-05    5
# 2020-01-06    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D  F
# 2020-01-01 -1.816116 -2.503185 -1.038084  0.691053  1
# 2020-01-02 -0.635515  2.322626 -0.626327 -1.341994  2
# 2020-01-03 -1.718989  0.163695 -2.324420  0.116682  3
# 2020-01-04 -1.485980 -0.310791  1.664451 -1.943485  4
# 2020-01-05  0.525827  1.085905  2.079685 -1.275683  5
# 2020-01-06 -0.478874  2.536959 -0.001792 -0.745353  6

# %%
df.iat[0,1] = 0
# 위치 통해 값 설정
df.at[dates[0],'A'] = 0
# 라벨 통해 값 설정
df.loc[:,'D'] = np.array([5]*len(df))
# Numpy 배열 사용한 할당 - ?
# np.array()
df
# Out:
#                    A         B         C  D  F
# 2020-01-01  0.000000  0.000000 -1.038084  5  1
# 2020-01-02 -0.635515  2.322626 -0.626327  5  2
# 2020-01-03 -1.718989  0.163695 -2.324420  5  3
# 2020-01-04 -1.485980 -0.310791  1.664451  5  4
# 2020-01-05  0.525827  1.085905  2.079685  5  5
# 2020-01-06 -0.478874  2.536959 -0.001792  5  6

# %%
df2 = df.copy()
df2[df2>0] = -df2
df2
# Out:
#                    A         B         C  D  F
# 2020-01-01  0.000000  0.000000 -1.038084 -5 -1
# 2020-01-02 -0.635515 -2.322626 -0.626327 -5 -2
# 2020-01-03 -1.718989 -0.163695 -2.324420 -5 -3
# 2020-01-04 -1.485980 -0.310791 -1.664451 -5 -4
# 2020-01-05 -0.525827 -1.085905 -2.079685 -5 -5
# 2020-01-06 -0.478874 -2.536959 -0.001792 -5 -6

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
# reindex -> 지정된 축 상 인덱스를 변경/추가/삭제 O
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D  F    E
# 2020-01-01  0.000000  0.000000 -1.038084  5  1  1.0
# 2020-01-02 -0.635515  2.322626 -0.626327  5  2  1.0
# 2020-01-03 -1.718989  0.163695 -2.324420  5  3  NaN
# 2020-01-04 -1.485980 -0.310791  1.664451  5  4  NaN

# %%
df1.dropna(how='any')
#  값 없는 행 삭제
# Out:
#                    A         B         C  D  F    E
# 2020-01-01  0.000000  0.000000 -1.038084  5  1  1.0
# 2020-01-02 -0.635515  2.322626 -0.626327  5  2  1.0

# %%
df1.fillna(value=5)
# 결측치 채워넣음
# Out:
#                    A         B         C  D  F    E
# 2020-01-01  0.000000  0.000000 -1.038084  5  1  1.0
# 2020-01-02 -0.635515  2.322626 -0.626327  5  2  1.0
# 2020-01-03 -1.718989  0.163695 -2.324420  5  3  5.0
# 2020-01-04 -1.485980 -0.310791  1.664451  5  4  5.0

# %%
pd.isna(df1)
# nan인 값에만 True표시
# Out:
#                 A      B      C      D      F      E
# 2020-01-01  False  False  False  False  False  False
# 2020-01-02  False  False  False  False  False  False
# 2020-01-03  False  False  False  False  False   True
# 2020-01-04  False  False  False  False  False   True

# %%
df
# Out:
#                    A         B         C  D  F
# 2020-01-01  0.000000  0.000000 -1.038084  5  1
# 2020-01-02 -0.635515  2.322626 -0.626327  5  2
# 2020-01-03 -1.718989  0.163695 -2.324420  5  3
# 2020-01-04 -1.485980 -0.310791  1.664451  5  4
# 2020-01-05  0.525827  1.085905  2.079685  5  5
# 2020-01-06 -0.478874  2.536959 -0.001792  5  6

# %%
df.mean()
# .mean() -> 평균 구하는 함수
# Out:
# A   -0.632255
# B    0.966399
# C   -0.041081
# D    5.000000
# F    3.500000
# dtype: float64

# %%
df.mean(1)
# 1번 축에서 실행
# Out:
# 2020-01-01    0.992383
# 2020-01-02    1.612157
# 2020-01-03    0.824057
# 2020-01-04    1.773536
# 2020-01-05    2.738283
# 2020-01-06    2.611259
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
# series(data,index)로 데이터배열 생성
# shift(2)로 데이터값 두칸씩 이동
s
# Out:
# 2020-01-01    NaN
# 2020-01-02    NaN
# 2020-01-03    1.0
# 2020-01-04    3.0
# 2020-01-05    5.0
# 2020-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis=0)
# sub(빼기) / add(더하기) -> 행에 대한 연산
# 평균계산 등을 할때 축axis 지정!
# axis=0 -> index기준 / axis=1 -> columns기준
# Out:
#                    A         B         C    D    F
# 2020-01-01       NaN       NaN       NaN  NaN  NaN
# 2020-01-02       NaN       NaN       NaN  NaN  NaN
# 2020-01-03 -2.718989 -0.836305 -3.324420  4.0  2.0
# 2020-01-04 -4.485980 -3.310791 -1.335549  2.0  1.0
# 2020-01-05 -4.474173 -3.914095 -2.920315  0.0  0.0
# 2020-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# cumsum -> 배열에서 주어진 축 따라 누적되는 원소들의 누적 합
# Out:
#                    A         B         C   D   F
# 2020-01-01  0.000000  0.000000 -1.038084   5   1
# 2020-01-02 -0.635515  2.322626 -1.664412  10   3
# 2020-01-03 -2.354504  2.486321 -3.988832  15   6
# 2020-01-04 -3.840484  2.175530 -2.324381  20  10
# 2020-01-05 -3.314657  3.261434 -0.244696  25  15
# 2020-01-06 -3.793531  5.798394 -0.246488  30  21

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    3
# 1    4
# 2    3
# 3    3
# 4    2
# 5    6
# 6    5
# 7    5
# 8    2
# 9    3
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    4
# 5    2
# 2    2
# 6    1
# 4    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# 소문자 변경함수 lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -0.340126  0.736802 -0.560872  1.712714
# 1 -1.009251 -1.425251  1.398806 -0.540034
# 2  0.847150  1.601578  0.199179 -0.164685
# 3  1.064560  1.313061  0.615670 -0.604231
# 4 -0.523376 -0.877245 -0.430081 -0.532193
# 5 -0.335711 -1.293081 -0.714754  1.079677
# 6 -0.092520 -0.229789  1.008696  2.059154
# 7 -0.460738  1.744245 -0.359977 -0.372503
# 8  0.499958 -0.893794  0.128332 -0.926800
# 9 -0.151213 -1.042763  0.708464  0.804004

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.340126  0.736802 -0.560872  1.712714
# 1 -1.009251 -1.425251  1.398806 -0.540034
# 2  0.847150  1.601578  0.199179 -0.164685
# 3  1.064560  1.313061  0.615670 -0.604231
# 4 -0.523376 -0.877245 -0.430081 -0.532193
# 5 -0.335711 -1.293081 -0.714754  1.079677
# 6 -0.092520 -0.229789  1.008696  2.059154
# 7 -0.460738  1.744245 -0.359977 -0.372503
# 8  0.499958 -0.893794  0.128332 -0.926800
# 9 -0.151213 -1.042763  0.708464  0.804004

# %%
left = pd.DataFrame({'key':['foo','bar'], 'lval':[1,2]})
right = pd.DataFrame({'key':['foo','bar'], 'rval':[4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.904455  0.685042 -0.954071  0.680736
# 1 -0.543193  0.429224  1.583960 -1.031491
# 2  1.124084  0.546814  1.396895  0.541248
# 3 -1.230714 -0.948277  1.595888 -0.862642
# 4  1.031669 -0.083083 -1.805997  0.306168
# 5 -1.288090  0.185698  0.295578 -0.177539
# 6  0.085461  1.074385  0.067939  1.925478
# 7  0.611538  0.791009  0.000285 -1.338425

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# ingore_index통해 iloc으로 가져온 index(3번)를 무시하고, 순서대로 index 배열
# Out:
#           A         B         C         D
# 0  0.904455  0.685042 -0.954071  0.680736
# 1 -0.543193  0.429224  1.583960 -1.031491
# 2  1.124084  0.546814  1.396895  0.541248
# 3 -1.230714 -0.948277  1.595888 -0.862642
# 4  1.031669 -0.083083 -1.805997  0.306168
# 5 -1.288090  0.185698  0.295578 -0.177539
# 6  0.085461  1.074385  0.067939  1.925478
# 7  0.611538  0.791009  0.000285 -1.338425
# 8 -1.230714 -0.948277  1.595888 -0.862642

# %%
df = pd.DataFrame(
    {
        'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C' : np.random.randn(8),
        'D' : np.random.randn(8)
    })
df
# Out:
#      A      B         C         D
# 0  foo    one -0.849343  0.919347
# 1  bar    one  0.269305  0.145725
# 2  foo    two  0.249222  0.519387
# 3  bar  three -1.039402 -0.528813
# 4  foo    two -0.611851 -1.171945
# 5  bar    two -1.175715 -1.684860
# 6  foo    one -0.415681  0.173045
# 7  foo  three -0.698016  0.250428

# %%
df.groupby('A').sum()
# A를 기준으로 그룹화! -> 각 그룹에 sum()적용
# Out:
#             C         D
# A
# bar -1.945812 -2.067948
# foo -2.325668  0.690263

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.269305  0.145725
#     three -1.039402 -0.528813
#     two   -1.175715 -1.684860
# foo one   -1.265023  1.092393
#     three -0.698016  0.250428
#     two   -0.362629 -0.652557

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))
# tuples -> 두 list인자들을 순서대로 묶은 배열을 인자로 가지는 list
index = pd.MultiIndex.from_tuples(tuples, names=['first','second'])
df = pd.DataFrame(np.random.randn(8,2), index = index, columns=['A','B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.212411  0.111157
#       two    -0.117586 -1.970596
# baz   one     0.630362 -2.275840
#       two    -1.629124 -2.375665
# foo   one    -0.315745 -0.171454
#       two    -1.352471  0.657942
# qux   one    -1.264904  1.232090
#       two    -0.106947  0.196732

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))
# tuples -> 두 list인자들을 순서대로 묶은 배열을 인자로 가지는 list
index = pd.MultiIndex.from_tuples(tuples, names=['first','second'])
df = pd.DataFrame(np.random.randn(8,2), index = index, columns=['A','B'])
df
df2 = df[:4]
# df를 위에서 4번째 까지 자르자!
df2
# Out:
#                      A         B
# first second
# bar   one     1.697459 -2.057720
#       two    -0.292862 -0.695876
# baz   one    -0.237077  1.163820
#       two    -0.397524 -0.476763

# %%
stacked = df2.stack()
# stack() -> 데이터프레임 열 계층 압축
stacked
# Out:
# first  second
# bar    one     A    1.697459
#                B   -2.057720
#        two     A   -0.292862
#                B   -0.695876
# baz    one     A   -0.237077
#                B    1.163820
#        two     A   -0.397524
#                B   -0.476763
# dtype: float64

# %%
stacked.unstack(1)
# stacked -> stack된! 가장 마지막 stack 데이터프레임 가져옴
# unstacked(0) -> index와 column 위치 대칭 이동
# Out:
# second        one       two
# first
# bar   A  1.697459 -0.292862
#       B -2.057720 -0.695876
# baz   A -0.237077 -0.397524
#       B  1.163820 -0.476763

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.976310  0.592802
# 1     one  B  foo -0.912995  1.374926
# 2     two  C  foo -0.356541  0.719061
# 3   three  A  bar -0.734784 -0.694771
# 4     one  B  bar  0.574726  0.477511
# 5     one  C  bar -0.227270  0.475803
# 6     two  A  foo  0.446541  0.681325
# 7   three  B  foo  0.469863  0.485245
# 8     one  C  foo  0.344044  1.504721
# 9     one  A  bar  0.027763 -1.846475
# 10    two  B  bar -0.386173 -1.255723
# 11  three  C  bar -0.521457 -1.544414

# %%
pd.pivot_table(df, values='D', index=['A','B'], columns=['C'])
# 대박편리 !
# pivot_table() ->> index를 데이터 내부 값으로 변경할 수 있다고 생각하자
# multiindex - 외부에서 가져온 값으로 index로 생각하면 될 듯
# Out:
# C             bar       foo
# A     B
# one   A  0.027763  0.976310
#       B  0.574726 -0.912995
#       C -0.227270  0.344044
# three A -0.734784       NaN
#       B       NaN  0.469863
#       C -0.521457       NaN
# two   A       NaN  0.446541
#       B -0.386173       NaN
#       C       NaN -0.356541

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a','b','b','a','a','e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a','b','b','a','a','e']})
df
df["grade"] = df["raw_grade"].astype("category")
# astype("category") -> 가공X 데이터를 범주형 데이터로 변환
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
# Series.cat.categories로 범주에 더 의미있는 이름 할당
df["grade"]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade grade
# 0   1         a   NaN
# 1   2         b   NaN
# 2   3         b   NaN
# 3   4         a   NaN
# 4   5         a   NaN
# 5   6         e   NaN

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     0
# bad          0
# medium       0
# good         0
# very good    0
# dtype: int64

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# plotting -> 그래프
# plot() -> 라벨이 존재하는 모든 열 그릴 때 편리

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])  
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df.to_csv('foo.csv')
# csv파일에 쓰기

# %%
pd.read_csv('foo.csv')
# csv파일 읽기
# Out:
#      Unnamed: 0          A          B          C         D
# 0    2000-01-01   0.360614   0.584311   2.078614  0.837829
# 1    2000-01-02   0.284949   1.742996   2.365070 -0.298445
# 2    2000-01-03   1.403079   2.957311   2.565024 -0.168766
# 3    2000-01-04   2.096322   1.340808   2.421761  0.736285
# 4    2000-01-05   1.960739   1.185975   4.019023  0.231826
# ..          ...        ...        ...        ...       ...
# 995  2002-09-22 -20.092787  33.100561 -19.986929 -3.817656
# 996  2002-09-23 -20.738321  33.584969 -19.938090 -3.818169
# 997  2002-09-24 -21.462458  35.255789 -18.464181 -4.007029
# 998  2002-09-25 -20.878018  34.099091 -16.660550 -5.781722
# 999  2002-09-26 -23.286524  33.977748 -17.761259 -5.143987
#
# [1000 rows x 5 columns]

# %%
df.to_hdf('foo.h5','df')
# HDF5 Store(날짜가 index인 파일인듯?)에 쓰기

# %%
pd.read_hdf('foo.h5','df')
# HDF5 Store 읽기
# Out:
#                     A          B          C         D
# 2000-01-01   0.360614   0.584311   2.078614  0.837829
# 2000-01-02   0.284949   1.742996   2.365070 -0.298445
# 2000-01-03   1.403079   2.957311   2.565024 -0.168766
# 2000-01-04   2.096322   1.340808   2.421761  0.736285
# 2000-01-05   1.960739   1.185975   4.019023  0.231826
# ...               ...        ...        ...       ...
# 2002-09-22 -20.092787  33.100561 -19.986929 -3.817656
# 2002-09-23 -20.738321  33.584969 -19.938090 -3.818169
# 2002-09-24 -21.462458  35.255789 -18.464181 -4.007029
# 2002-09-25 -20.878018  34.099091 -16.660550 -5.781722
# 2002-09-26 -23.286524  33.977748 -17.761259 -5.143987
#
# [1000 rows x 4 columns]

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')
# excel 파일에 쓰기

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# excel파일 읽기
# Out:
#     Unnamed: 0          A          B          C         D
# 0   2000-01-01   0.360614   0.584311   2.078614  0.837829
# 1   2000-01-02   0.284949   1.742996   2.365070 -0.298445
# 2   2000-01-03   1.403079   2.957311   2.565024 -0.168766
# 3   2000-01-04   2.096322   1.340808   2.421761  0.736285
# 4   2000-01-05   1.960739   1.185975   4.019023  0.231826
# ..         ...        ...        ...        ...       ...
# 995 2002-09-22 -20.092787  33.100561 -19.986929 -3.817656
# 996 2002-09-23 -20.738321  33.584969 -19.938090 -3.818169
# 997 2002-09-24 -21.462458  35.255789 -18.464181 -4.007029
# 998 2002-09-25 -20.878018  34.099091 -16.660550 -5.781722
# 999 2002-09-26 -23.286524  33.977748 -17.761259 -5.143987
#
# [1000 rows x 5 columns]
